# %%
import math, string, random, itertools, copy
import numpy as np
from numpy import float32
from math import sqrt
import matplotlib.pyplot as plt
from scipy.stats import poisson
from copy        import deepcopy
import time
import h5py

# %%
maxJets  = 20
nInputs  = maxJets * 4 + 2                    # Maximum number of Jets x 4-momentum + METx,y              
nOutputs = 1                                  # Trigger Bit: 0 or 1

# %%
print 'MaxJets=',maxJets,'nInputs=',nInputs, 'nOutputs=',nOutputs
# Out:
# MaxJets= 20 nInputs= 82 nOutputs= 1

# %%
# For Histograms:
# ------------------
V_JetsMass=[]
V_JetsPx  =[]
V_JetsPy  =[]
V_JetsPz  =[]
V_JetsP   =[]
V_JetsE   =[]
V_METx    =[]
V_METy    =[]
# -------------------

nEvents=1000000                                    # Number of Events = 1 000 000
nJetsPerEvent=np.random.poisson(6,size=nEvents)     # Number of Jets per event = Poisson(6)
nDeco = 3 

target_matrix=np.zeros((nEvents,1), dtype=float32)
input_matrix =np.zeros((nEvents, nInputs), dtype=float32)
decorator_matrix = np.zeros((nEvents, nDeco), dtype=float32)

nPass1=0
nFail1=0

px_values = []
start = time.mktime(time.gmtime())

for iEvent in range(nEvents):          #Loop over all events
    
    nJets=nJetsPerEvent[iEvent]  
    
    if(nJets <= 20 and nJets>=2): 
        ## to be corrected, we cannot truncate the events at maxJets
    
        n_Ex_miss=random.gauss(0,3)
        n_Ey_miss=random.gauss(0,3)

        MET= [n_Ex_miss,n_Ey_miss]

        V_METx.append(n_Ex_miss)
        V_METy.append(n_Ey_miss)
        
        Jets_P4=[]    
    
        for iJet in range(nJets):   
            
            # Synthetic Data
            n_Mass  = random.expovariate(0.165) 
            n_Px    = random.gauss(0,3)        
            n_Py    = random.gauss(0,3)
            n_Pz    = random.gauss(0,6)           
            n_P  = sqrt((n_Px)**2 + (n_Py)**2+(n_Pz)**2)    
            n_E  = sqrt((n_P)**2  + (n_Mass)**2)
        
            V_JetsMass.append(n_Mass)
            V_JetsPx.append(n_Px)
            V_JetsPy.append(n_Py)
            V_JetsPz.append(n_Pz)
            V_JetsP.append(n_P)
            V_JetsE.append(n_E)
        
            iJetP4=(n_E,n_Px,n_Py,n_Pz)

            Jets_P4.append( iJetP4 )
            px_values.append( n_Px )
            
        # ---------------------------------------------------------
        def getKey(item):
            return sqrt(item[1]*item[1]+item[2]*item[2])
        # ---------------------------------------------------------
        
        # Jets are sorted based on their Pt
        Jets_P4=sorted(Jets_P4,key=getKey,reverse=True)     

        ## the event is generated, copy the information in the input matrix
        for ijet,jet in enumerate(Jets_P4):
            if ijet>=maxJets: break
            input_matrix[iEvent,ijet*4:ijet*4+4] = [jet[i] for i in range(4)]
        input_matrix[iEvent,-2] = MET[0]
        input_matrix[iEvent,-1] = MET[1]
    
        #print Jets_P4
        #print input_matrix[iEvent][:], len(Jets_P4), "jets"
        #print
        
        
        minMass=999999.0    
        MJ_Px = None
        MJ1_Px=0
        MJ1_Py=0
        MJ1_Pz=0
        MJ1_E =0
        MJ2_Px=0
        MJ2_Py=0
        MJ2_Pz=0
        MJ2_E =0
   
        
        for jeti, jet  in enumerate(Jets_P4):            
            
            if not MJ_Px: 
                MJ_Px=jet[1]
                MJ_Py=jet[2]
                MJ_Pz=jet[3]
                MJ_E =jet[0]
            else:
                MJ_Px+=jet[1]
                MJ_Py+=jet[2]
                MJ_Pz+=jet[3]
                MJ_E +=jet[0]   
        
        minMJ1=None
        minMJ2=None

        
        
        for nmega1 in range(1,len(Jets_P4)/2+1):
            
            for combination in itertools.combinations(Jets_P4, nmega1):
                    
                MJ2_Px=MJ_Px
                MJ2_Py=MJ_Py
                MJ2_Pz=MJ_Pz
                MJ2_E =MJ_E
            
                MJ1_Px=None
                MJ1_Py=None
                MJ1_Pz=None
                MJ1_E =None
                
                for jet in combination:
                    
                    MJ2_Px-=jet[1]
                    MJ2_Py-=jet[2]
                    MJ2_Pz-=jet[3]
                    MJ2_E -=jet[0] 
                
                    if MJ1_Px: 
                    
                        MJ1_Px+=jet[1]
                        MJ1_Py+=jet[2]
                        MJ1_Pz+=jet[3]
                        MJ1_E +=jet[0]
                    
                    else: 
                    
                        MJ1_Px=jet[1]
                        MJ1_Py=jet[2]
                        MJ1_Pz=jet[3]
                        MJ1_E =jet[0]
             
                
                P_MJ1=sqrt((MJ1_Px)**2+(MJ1_Py)**2+(MJ1_Pz)**2)            
                P_MJ2=sqrt((MJ2_Px)**2+(MJ2_Py)**2+(MJ2_Pz)**2)
            
            
                Mass2_MJ1= MJ1_E*MJ1_E - P_MJ1*P_MJ1 
                Mass2_MJ2= MJ2_E*MJ2_E - P_MJ2*P_MJ2
            
                SumMass=Mass2_MJ1+Mass2_MJ2
                if(SumMass < minMass) or minMJ1==None or minMJ2==None:
                    minMass=SumMass
                    minMJ1 = (MJ1_E, MJ1_Px, MJ1_Py, MJ1_Pz)
                    minMJ2 = (MJ2_E, MJ2_Px, MJ2_Py, MJ2_Pz)
            
    
        # -------------------------------------------------------------------------------- 
        def RazorVariables(MegaJet1, MegaJet2, MET):
            magPj1= sqrt(MegaJet1[1]**2+ MegaJet1[2]**2+MegaJet1[3]**2)
            magPj2= sqrt(MegaJet2[1]**2+ MegaJet2[2]**2+MegaJet2[3]**2)
            Pt_j1 = sqrt(MegaJet1[1]**2 + MegaJet1[2]**2)
            Pt_j2 = sqrt(MegaJet2[1]**2 + MegaJet2[2]**2)
            EtPj12_dot = MET[0] * MegaJet1[1] + MET[1]*MegaJet1[2] + MET[0]*MegaJet2[1] + MET[1]*MegaJet2[2]
            MissingEt = sqrt(MET[0]**2 + MET[1]**2)
       
            M_R = sqrt( (magPj1 + magPj2)**2 - (MegaJet1[3]+MegaJet2[3])**2)   
            MR_T = sqrt( 1.0/2.0 * ( MissingEt * (Pt_j1+Pt_j2) - EtPj12_dot))
            R = MR_T / M_R 
            return M_R,MR_T,R
        # --------------------------------------------------------------------------------
    
    
        
        M_R,MR_T,R = RazorVariables (minMJ1,minMJ2,MET)
    
    
        if(M_R*R*R > 0.6):
            nPass1+=1
            target_matrix[iEvent]=1
        else:
            nFail1+=1
            target_matrix[iEvent]=0
    
                
        decorator_matrix[iEvent][0] = R*R
        decorator_matrix[iEvent][1] = M_R
        decorator_matrix[iEvent][2] = 0.6/M_R   
    
stop = time.mktime(time.gmtime())
print "took",stop-start,"[s]"
print "took",(stop-start)/nEvents,"[s]/event"

print "Pass1=",nPass1,"(" ,nPass1*100.0/(nPass1+nFail1),"%)"
print "Fail1=",nFail1, "(",nFail1*100.0/(nPass1+nFail1),"%)"
print "All =" ,nPass1+nFail1

Pass=[]
for i in range(nPass1):
    Pass.append(1.0)
Fail=[]
for i in range(nFail1):
    Fail.append(2.0)
# Out:
# took 2574.0 [s]
# took 0.002574 [s]/event
# Pass1= 598365 ( 60.8795493185 %)
# Fail1= 384502 ( 39.1204506815 %)
# All = 982867

# %%
print "Number of Events Generated                  =", nEvents
print "Number of Events with (nJets >= 2 and <=20) =", nPass1+nFail1
print "Number of Events that give zeros            =", nEvents-(nPass1+nFail1), " (", (nEvents-(nPass1+nFail1))/float(nEvents)*100,"%)"
print "Number of Events with 0 Jets                =", len(np.where(nJetsPerEvent[np.where(input_matrix[:,0] ==0)[0]] == 0)[0]), " out of ", nEvents-(nPass1+nFail1)
print "Number of Events with 1 Jet                 =", len(np.where(nJetsPerEvent[np.where(input_matrix[:,0] == 0)[0]] == 1)[0])," out of ", nEvents-(nPass1+nFail1)
print "Events with 0 and 1 Jet                     =", len(np.where(nJetsPerEvent[np.where(input_matrix[:,0] ==0)[0]] == 0)[0])+len(np.where(nJetsPerEvent[np.where(input_matrix[:,0] == 0)[0]] == 1)[0])
print "Events with nJets>20                        =", len(np.where(nJetsPerEvent[np.where(input_matrix[:,0] ==0)[0]] > 20)[0])
# Out:
# Number of Events Generated                  = 1000000
# Number of Events with (nJets >= 2 and <=20) = 982867
# Number of Events that give zeros            = 17133  ( 1.7133 %)
# Number of Events with 0 Jets                =
# 2440  out of  17133
# Number of Events with 1 Jet                 = 14691  out of  17133
# Events with 0 and 1 Jet                     =
# 17131
# Events with nJets>20                        = 2

# %%
IN_matrix  =np.zeros(((nPass1+nFail1),nInputs), dtype=float32)
TAR_matrix =np.zeros(((nPass1+nFail1),1)      , dtype=float32)
DEC_matrix =np.zeros(((nPass1+nFail1),nDeco)  , dtype=float32)

# %%
j=0
for i, iEvent in enumerate(input_matrix):
    count_zeros=0
    for iInput in iEvent:
        if(iInput == 0.0):
            count_zeros+=1
    if(count_zeros != nInputs):
        IN_matrix[j] =iEvent
        TAR_matrix[j]=target_matrix[i]
        DEC_matrix[j]=decorator_matrix[i]
        j+=1

# %%
f=h5py.File("data/data.hdf5", mode="w")
sg = f.create_group("data")
sg.create_dataset("input", data=IN_matrix)
sg.create_dataset("target", data=TAR_matrix)
sg.create_dataset("deco", data=DEC_matrix)
f.close()

# %%
plt.hist(TAR_matrix, bins=[-0.05, 0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65,0.75,0.85,0.95,1.05])
plt.xlabel("Trigger Bit")
plt.ylabel("Number of Events")
plt.grid(True)
plt.ylim([0,650000])
plt.xlim([-0.1,1.1])
show()

# %%
R2_Values  =[]
MR_Values  =[]
Cut_Values =[]

for i, iEvent in enumerate(DEC_matrix):
    R2_Values.append(iEvent[0])
    MR_Values.append(iEvent[1])
    Cut_Values.append(iEvent[2])

# %%
from matplotlib.colors import LogNorm
plt.hist2d(MR_Values, R2_Values, norm=LogNorm(), bins=200)
plt.grid(True)
plt.xlabel("$M_{R}$", size=15)
plt.ylabel("$R^{2}$",size=15)
plt.title("$R^{2}=f(M_{R})$", size=15)
plt.ylim([0,2.0])
plt.xlim([0,60])
cmap=plt.get_cmap('jet')
plt.colorbar(label='Number of Events')
show()

# %%
#plt.scatter(MR_Values, Cut_Values, color='r', linestyle='-')

# %%
bins=[-0.5,0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.8,8.5,9.5,10.5,11.5,12.5,13.5,14.5,15.5,16.5,17.5,18.5,19.5,20.5]
plt.hist(np.random.poisson(6,size=nEvents), bins=bins)
plt.xlim([-0.5,20.5])
plt.grid(True)
plt.xlabel("Number of Jets", size=15)
plt.ylabel("Number of Events", size=15)
#plt.title("Number of Jets distribution", size=15)

# %%
plt.hist(V_JetsMass,bins=100)
plt.xlabel("Mass $[GeV/c^{2}]$", size=15)
plt.ylabel("Number of Jets", size=15)
plt.grid(True)
show()

plt.hist(V_JetsPx,bins=100)
plt.xlabel("$P_{x} [GeV/c]$", size=15)
plt.ylabel("Number of Jets", size=15)
plt.grid(True)
show()

plt.hist(V_JetsPy,bins=100)
plt.xlabel("$P_{y} [GeV/c]$",size=15)
plt.ylabel("Number of Jets", size=15)
plt.grid(True)
show()

plt.hist(V_JetsPz,bins=100)
plt.xlabel("$P_{z} [GeV/c]$",size=15)
plt.ylabel("Number of Jets", size=15)
plt.grid(True)
show()

plt.hist(V_JetsP,bins=100)
plt.xlabel("$P [GeV/c]$",size=15)
plt.ylabel("Number of Jets",size=15)
plt.grid(True)
show()

plt.hist(V_JetsE,bins=100)
plt.xlabel("$E [GeV]$",size=15)
plt.ylabel("Number of Jets",size=15)
plt.grid(True)
show()

plt.hist(V_METx,bins=100)
plt.xlabel("$E_{x}^{miss}$ [GeV]", size=15)
plt.ylabel("Number of Events"    ,size=15)
plt.grid(True)
show()

plt.hist(V_METy,bins=100)
plt.xlabel("$E_{y}^{miss}$ [GeV]",size=15)
plt.ylabel("Number of Events",size=15)
plt.grid(True)
show()

# %%
V_pT  =[]
V_MET =[]

for i, iEvent in enumerate(V_METx):
    V_MET.append(sqrt(iEvent**2+V_METy[i]*V_METy[i]))
    
for i, iJet in enumerate(V_JetsPx):
    V_pT.append(sqrt(iJet**2+V_JetsPy[i]*V_JetsPy[i]))

# %%
plt.hist(V_MET, bins=100)
plt.xlabel("$E^{miss}$ $[GeV]$",size=15)
plt.ylabel("Number of Events",size=15)
plt.grid(True)
show()

# %%
plt.hist(V_pT, bins=100)
plt.xlabel("$p_{T}$ $[GeV/c]$",size=15)
plt.ylabel("Number of Jets",size=15)
plt.grid(True)
show()
